# %%
import pandas as pd

# %%
categories = [
    'Automobile',
    'Beverages',
    'Clothing',
    'Electronics',
    'Entertainment',
    'Food',
    'Jewellery',
    'Makeup',
    'Non-profit',
    'Shoes'
]

quadrant = [
    'HF-HE',
    'HF-LE',
    'LF-HE',
    'LF-LE',
]

global_df = pd.DataFrame()
for category in categories:
    for quad in quadrant:
        path = f"D://Study//Project//Major project-1//Hashtag analysis//{category}//{quad}_hashtag//{quad}_hashtags.xlsx"
        df = pd.read_excel(path)
        df['Category'] = category
        df['Quadrant'] = quad
        global_df = pd.concat([global_df, df])

# %%
global_df.head()
# Out:
#    Followers  Engagement     Influencers  \
# 0    97885.0    0.467518    hkmatthews50
# 1    97885.0    0.467518    hkmatthews50
# 2    97885.0    0.467518    hkmatthews50
# 3    97885.0    0.467518    hkmatthews50
# 4    96646.0    0.604077  dhillon_balbir
#
#                                        Urls  \
# 0  https://www.instagram.com/p/CqLoEGFv-yo/
# 1  https://www.instagram.com/p/Cpk6qDQSW6B/
# 2  https://www.instagram.com/p/Cpx7QyfvGNU/
# 3  https://www.instagram.com/p/Cp7vUGhP3Kj/
# 4  https://www.instagram.com/p/C3FpBJFPfU2/
#
#                                              Img-url  \
# 0  https://www.instagram.com/p/CqLoEGFv-yo/media/...
# 1  https://www.instagram.com/p/Cpk6qDQSW6B/media/...
# 2  https://www.instagram.com/p/Cpx7QyfvGNU/media/...
# 3  https://www.instagram.com/p/Cp7vUGhP3Kj/media/...
# 4  https://www.instagram.com/p/C3FpBJFPfU2/media/...
#
#                                             Captions  \
# 0  Stormed into the Final and HOW! 🔥\n\nReady wit...
# ...

# %%
global_df.shape
# Out:
# (28718, 10)

# %%
global_df.to_excel('All_hashtag.xlsx', index=False)

# %%
new_df = pd.read_excel(r'C:\Users\nishi\OneDrive\Desktop\Irrelevent_hashtags.xlsx')

# %%
new_df.head()
# Out:
#    Followers  Engagement     Influencers  \
# 0      97885    0.467518    hkmatthews50
# 1      97885    0.467518    hkmatthews50
# 2      97885    0.467518    hkmatthews50
# 3      97885    0.467518    hkmatthews50
# 4      96646    0.604077  dhillon_balbir
#
#                                        Urls  \
# 0  https://www.instagram.com/p/CqLoEGFv-yo/
# 1  https://www.instagram.com/p/Cpk6qDQSW6B/
# 2  https://www.instagram.com/p/Cpx7QyfvGNU/
# 3  https://www.instagram.com/p/Cp7vUGhP3Kj/
# 4  https://www.instagram.com/p/C3FpBJFPfU2/
#
#                                              Img-url  \
# 0  https://www.instagram.com/p/CqLoEGFv-yo/media/...
# 1  https://www.instagram.com/p/Cpk6qDQSW6B/media/...
# 2  https://www.instagram.com/p/Cpx7QyfvGNU/media/...
# 3  https://www.instagram.com/p/Cp7vUGhP3Kj/media/...
# 4  https://www.instagram.com/p/C3FpBJFPfU2/media/...
#
#                                             Captions  \
# 0  Stormed into the Final and HOW! 🔥\n\nReady wit...
# ...

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# df['Average Words'] = pd.to_numeric(df['Average Words'], errors='coerce')

# Calculate the average follower/post for each quadrant within each category
contrast_colors = ['#90E0EF', '#00B4D8', '#0077B6', '#03045E']
cmap = LinearSegmentedColormap.from_list('contrast', contrast_colors, N=256)
average_df = new_df.groupby(['Category', 'Quadrant'])['irrelevant_hashtag_clustering_based'].mean().reset_index()

# Pivot the dataframe for better plotting
pivot_df = average_df.pivot(index='Category', columns='Quadrant', values='irrelevant_hashtag_clustering_based')

print('Average No. of Words across Quadrants and Categories')
print(pivot_df.values)
# Plotting
pivot_df.plot(kind='bar', figsize=(14, 8), colormap=cmap)
# plt.title('Average No. of Words across Quadrants and Categories')
plt.ylabel('Average No. of Words per Quadrants')
plt.xlabel('Category')
plt.xticks(rotation=45)
plt.legend(title='Quadrant')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# Average No. of Words across Quadrants and Categories
# [[ 1.97183099  2.55194805  2.46406571  3.26923077]
#  [ 3.01675978  4.6175      3.04752475  6.23529412]
#  [ 0.71142857  2.20233307  0.95788443  2.3029316 ]
#  [ 0.51677852  2.22142857  0.87608069  3.37837838]
#  [ 0.82462462  2.39090909  1.76426706  2.12738854]
#  [ 3.94936709  9.54545455  4.21333333  5.08333333]
#  [ 2.45528455  3.9144385   4.81038647  3.9       ]
#  [ 6.91860465  7.94915254  5.34285714 10.33333333]
#  [ 2.42982456  3.19281046  5.27027027  1.5       ]
#  [ 2.3940678   3.53588517  3.85837583  4.48979592]]
